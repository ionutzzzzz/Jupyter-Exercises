# %% [markdown]
# # Chapter 6: Support Vector Machines & Naive Bayes
#
# In this notebook, we cover two classical and powerful classification algorithms:
#
# ## 1. Support Vector Machines (SVM)
# SVM aims to find the optimal hyperplane that separates classes with the maximum margin.
# - **Support Vectors**: The data points closest to the decision boundary.
# - **Kernel Trick**: Projects data into a higher-dimensional space to make it linearly separable. Common kernels: Linear, Polynomial, and Radial Basis Function (RBF).
# - **Hyperparameters**:
#   - `C`: Controls the trade-off between maximizing margin and minimizing classification errors.
#
# ## 2. Naive Bayes
# Naive Bayes is a probabilistic classifier based on Bayes' Theorem:
# $$P(y \mid x_1...x_n) = \frac{P(y) P(x_1...x_n \mid y)}{P(x_1...x_n)}$$
# It makes the **"naive" assumption** that features are conditionally independent given the class label. Very popular for text classification and spam detection.

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import numpy as np

# Sample SVM classification
X = np.array([[1, 2], [2, 3], [3, 1], [6, 5], [7, 8], [8, 6]])
y = np.array([0, 0, 0, 1, 1, 1])

clf = SVC(kernel='linear').fit(X, y)
print("Support Vectors:
", clf.support_vectors_)

# %% [markdown]
# ---
# ## Exercises
#
# Now it is your turn! Run the verification code cell after each exercise to check your answers.
#
# ### Exercise 1: Import Naive Bayes (Easy)
# Import `MultinomialNB` from `sklearn.naive_bayes` and instantiate it. Store it in a variable named `nb_easy`.

# %%
# TODO: Import and instantiate MultinomialNB
nb_easy = ____
print(nb_easy)

# %%
from learntools import ch6
ch6.step_1.check(nb_easy)
# ch6.step_1.hint()
# ch6.step_1.solution()

# %% [markdown]
# ### Exercise 2: Linear SVM Instantiation (Easy)
# Import `SVC` from `sklearn.svm` and instantiate it with a `'linear'` kernel. Store the model in `svm_easy`.

# %%
# TODO: Import SVC and instantiate with kernel='linear'
svm_easy = ____
print(svm_easy)

# %%
ch6.step_2.check(svm_easy)
# ch6.step_2.hint()
# ch6.step_2.solution()

# %% [markdown]
# ### Exercise 3: Compute Probability Output (Easy)
# For a trained Support Vector Machine model `model`, predict probabilities on `X_test`. Store the result in `probs`.

# %%
from sklearn.svm import SVC
# Assuming probability support is enabled
X = np.array([[1], [2], [3], [4]])
y = np.array([0, 0, 1, 1])
model = SVC(kernel='linear', probability=True).fit(X, y)
X_test = np.array([[2.5]])
# TODO: Predict probability
probs = ____
print(probs)

# %%
ch6.step_3.check(probs)
# ch6.step_3.hint()
# ch6.step_3.solution()

# %% [markdown]
# ### Exercise 4: Import Naive Bayes (Easy)
# Import `MultinomialNB` from `sklearn.naive_bayes` and instantiate it. Store it in a variable named `nb_easy`.

# %%
# TODO: Import and instantiate MultinomialNB
nb_easy = ____
print(nb_easy)

# %%
ch6.step_4.check(nb_model)
# ch6.step_4.hint()
# ch6.step_4.solution()

# %% [markdown]
# ### Exercise 2: Linear SVM Instantiation (Easy)
# Import `SVC` from `sklearn.svm` and instantiate it with a `'linear'` kernel. Store the model in `svm_easy`.

# %%
# TODO: Import SVC and instantiate with kernel='linear'
svm_easy = ____
print(svm_easy)

# %%
ch6.step_5.check(svm_model, svm_model.support_)
# ch6.step_5.hint()
# ch6.step_5.solution()

# %% [markdown]
# ### Exercise 3: Compute Probability Output (Easy)
# For a trained Support Vector Machine model `model`, predict probabilities on `X_test`. Store the result in `probs`.

# %%
from sklearn.svm import SVC
# Assuming probability support is enabled
X = np.array([[1], [2], [3], [4]])
y = np.array([0, 0, 1, 1])
model = SVC(kernel='linear', probability=True).fit(X, y)
X_test = np.array([[2.5]])
# TODO: Predict probability
probs = ____
print(probs)

# %%
ch6.step_6.check(acc_linear, acc_rbf)
# ch6.step_6.hint()
# ch6.step_6.solution()
