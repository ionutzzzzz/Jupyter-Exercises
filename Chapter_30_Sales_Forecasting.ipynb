# %% [markdown]
# # Chapter 30: Daily Sales Forecasting (Time Series Case Study)
#
# In this project, you will build a time series forecasting model to predict daily sales (`data/daily_sales.csv`). You will load sales data, compute rolling average characteristics, perform ADF stationarity tests, differencing models, fit ARIMA models, and evaluate forecast performance.
#
# ## Workflow Overview
# 1. **Load and Format**: Load the series index, parse date formatting, and format indices.
# 2. **Feature Extraction**: Calculate rolling statistics (moving means and variances).
# 3. **Stationarity Testing**: Perform Augmented Dickey-Fuller stationarity check.
# 4. **Differencing**: Apply differencing transforms to make data stationary.
# 5. **ARIMA Model**: Fit an Autoregressive Integrated Moving Average regression.
# 6. **MAPE Score Evaluation**: Calculate forecasting accuracy metrics.

# %%
import numpy as np
import pandas as pd

sales = pd.read_csv('data/daily_sales.csv')
print("Daily Sales head:")
print(sales.head())

# %% [markdown]
# ---
# ## Exercises
#
# ### Exercise 1: Generate and Load Sales Data (Easy)
# Write a function `load_sales_data(file_path)` that loads the daily sales CSV file, parses the `'Date'` column into pandas Datetime objects, sets `'Date'` as the index, and returns the `'Sales'` column as a pandas Series.

# %%
def load_sales_data(file_path):
    # TODO: Load CSV, parse date, set index Date, return Sales series
    pass

# %%
from learntools import proj6
proj6.step_1.check(load_sales_data)
# proj6.step_1.hint()
# proj6.step_1.solution()

# %% [markdown]
# ### Exercise 2: Compute Rolling Features (Medium)
# Write a function `compute_rolling_sales(series, window=7)` that returns a tuple of pandas Series: `(rolling_mean, rolling_std)` calculated using the specified moving window.

# %%
def compute_rolling_sales(series, window=7):
    # TODO: Compute and return (rolling_mean, rolling_std) Series
    pass

# %%
proj6.step_2.check(compute_rolling_sales)
# proj6.step_2.hint()
# proj6.step_2.solution()

# %% [markdown]
# ### Exercise 3: ADF Stationarity Test (Medium)
# Write a function `check_sales_stationarity(series)` that performs an Augmented Dickey-Fuller test using `statsmodels.tsa.stattools.adfuller` and returns the resulting **p-value** as a float.

# %%
from statsmodels.tsa.stattools import adfuller

def check_sales_stationarity(series):
    # TODO: Run ADF test and return p-value
    pass

# %%
proj6.step_3.check(check_sales_stationarity)
# proj6.step_3.hint()
# proj6.step_3.solution()

# %% [markdown]
# ### Exercise 4: Time Series Differencing (Medium)
# Write a function `difference_sales(series, order=1)` that computes the difference of the Series at the specified lag order, drops missing values, and returns the differenced Series.

# %%
def difference_sales(series, order=1):
    # TODO: Difference the series and drop missing values
    pass

# %%
proj6.step_4.check(difference_sales)
# proj6.step_4.hint()
# proj6.step_4.solution()

# %% [markdown]
# ### Exercise 5: Fit ARIMA Model (Hard)
# Write a function `fit_arima_sales(series, order=(1,1,1))` that fits an ARIMA model using `statsmodels.tsa.arima.model.ARIMA` on the input time series and returns the fitted model results object.

# %%
from statsmodels.tsa.arima.model import ARIMA

def fit_arima_sales(series, order=(1,1,1)):
    # TODO: Fit ARIMA model and return fitted results wrapper
    pass

# %%
proj6.step_5.check(fit_arima_sales)
# proj6.step_5.hint()
# proj6.step_5.solution()

# %% [markdown]
# ### Exercise 6: Evaluate Forecast MAPE (Hard)
# Write a function `evaluate_forecast_mape(y_true, y_pred)` that computes and returns the **Mean Absolute Percentage Error (MAPE)** expressed as a float percentage (e.g. `12.5` for 12.5%).

# %%
def evaluate_forecast_mape(y_true, y_pred):
    # TODO: Compute Mean Absolute Percentage Error as percentage float value
    pass

# %%
proj6.step_6.check(evaluate_forecast_mape)
# proj6.step_6.hint()
# proj6.step_6.solution()
