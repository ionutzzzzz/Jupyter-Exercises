# %% [markdown]
# # Chapter 28: Iris Flower Classification (Multi-class Case Study)
#
# In this project, you will build a multi-class classification pipeline to predict flower species using structural attributes of Iris flowers (`data/iris.csv`). You will explore features, map target labels, split and scale characteristics, and train both Decision Trees and Naive Bayes classifiers before evaluating multiclass performance.
#
# ## Workflow Overview
# 1. **Load and Explore**: Load the CSV file and calculate species distributions.
# 2. **Target Encoding**: Convert species names into integer labels.
# 3. **Preprocessing**: Apply `StandardScaler` to numeric columns.
# 4. **Model Training**: Fit Decision Trees and Naive Bayes models.
# 5. **Evaluation**: Compute multi-class precision, recall, and F1-score for each species.

# %%
import numpy as np
import pandas as pd

# Load the dataset
df = pd.read_csv('data/iris.csv')
print("Iris shape:", df.shape)
print(df.head())

# %% [markdown]
# ---
# ## Exercises
#
# ### Exercise 1: Load and Explore Iris Data (Easy)
# Write a function `load_iris_data(file_path)` that loads the Iris dataset and returns a tuple containing: `(df.shape, species_value_counts)`.

# %%
def load_iris_data(file_path):
    # TODO: Load dataset and return (shape, species_counts)
    pass

# %%
from learntools import proj4
proj4.step_1.check(load_iris_data)
# proj4.step_1.hint()
# proj4.step_1.solution()

# %% [markdown]
# ### Exercise 2: Encode Target Labels (Easy)
# Write a function `encode_species(df)` that returns a 1D NumPy array of encoded target labels where `'setosa'` maps to `0`, `'versicolor'` maps to `1`, and `'virginica'` maps to `2`.

# %%
def encode_species(df):
    # TODO: Encode species names to integers and return array
    pass

# %%
proj4.step_2.check(encode_species)
# proj4.step_2.hint()
# proj4.step_2.solution()

# %% [markdown]
# ### Exercise 3: Split and Scale Features (Medium)
# Write a function `scale_iris_features(df)` that drops the target `'Species'` column, scales features to 0 mean and unit variance using `sklearn.preprocessing.StandardScaler`, and returns a tuple `(X_scaled, y)` where `y` is the raw target labels array.

# %%
from sklearn.preprocessing import StandardScaler

def scale_iris_features(df):
    # TODO: Scale features and return (X_scaled, y)
    pass

# %%
proj4.step_3.check(scale_iris_features)
# proj4.step_3.hint()
# proj4.step_3.solution()

# %% [markdown]
# ### Exercise 4: Train Decision Tree Classifier (Medium)
# Write a function `train_iris_dt(X_train, X_test, y_train, y_test)` that:
# 1. Fits a `DecisionTreeClassifier(max_depth=3, random_state=42)` on the training set.
# 2. Evaluates the accuracy on the test set.
# 3. Returns a tuple `(model, test_accuracy)`.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

def train_iris_dt(X_train, X_test, y_train, y_test):
    # TODO: Train Decision Tree and return (model, test_acc)
    pass

# %%
proj4.step_4.check(train_iris_dt)
# proj4.step_4.hint()
# proj4.step_4.solution()

# %% [markdown]
# ### Exercise 5: Train Naive Bayes Baseline (Medium)
# Write a function `train_iris_nb(X_train, X_test, y_train, y_test)` that fits a `GaussianNB` classifier on the training set and returns its classification accuracy on the test set.

# %%
from sklearn.naive_bayes import GaussianNB

def train_iris_nb(X_train, X_test, y_train, y_test):
    # TODO: Train GaussianNB and return accuracy score
    pass

# %%
proj4.step_5.check(train_iris_nb)
# proj4.step_5.hint()
# proj4.step_5.solution()

# %% [markdown]
# ### Exercise 6: Multi-class Confusion Matrix Metrics (Hard)
# Write a function `get_multiclass_metrics(y_true, y_pred)` that uses `precision_recall_fscore_support` with `average=None` to compute metrics for each class, and returns a dictionary mapping each class index (`0`, `1`, `2`) to its respective **F1-score**.

# %%
from sklearn.metrics import precision_recall_fscore_support

def get_multiclass_metrics(y_true, y_pred):
    # TODO: Calculate F1 scores for each class and return dictionary mapping label to f1-score
    pass

# %%
proj4.step_6.check(get_multiclass_metrics)
# proj4.step_6.hint()
# proj4.step_6.solution()
