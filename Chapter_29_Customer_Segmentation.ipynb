# %% [markdown]
# # Chapter 29: Customer Segmentation (Unsupervised Case Study)
#
# In this project, you will build an unsupervised clustering pipeline to group customers based on their usage profiles (`data/customer_churn.csv`). You will explore features, compute the optimal number of clusters using the Elbow Method, train K-Means model, evaluate cluster structure using Silhouette Scores, reduce dimensions using PCA, and profile cluster characteristics.
#
# ## Workflow Overview
# 1. **Feature Preparation**: Load features and scale them.
# 2. **Elbow Method**: Loop over K values to calculate cluster inertia.
# 3. **Clustering**: Train a K-Means model with optimal K.
# 4. **Evaluation**: Compute Silhouette scores.
# 5. **Dimensionality Reduction**: Apply PCA to visualize profiles in 2D.
# 6. **Profiling**: Group data by cluster centers and compute characteristic averages.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/customer_churn.csv')
print("Customer Churn shape:", df.shape)
print(df.head())

# %% [markdown]
# ---
# ## Exercises
#
# ### Exercise 1: Select Clustering Features (Easy)
# Write a function `get_clustering_data(file_path)` that loads the churn dataset, drops `CustomerID` and `Churn`, scales the remaining columns using `sklearn.preprocessing.MinMaxScaler` to range `[0, 1]`, and returns the dense NumPy feature array.

# %%
from sklearn.preprocessing import MinMaxScaler

def get_clustering_data(file_path):
    # TODO: Load dataset, drop CustomerID/Churn, apply MinMaxScaler and return dense array
    pass

# %%
from learntools import proj5
proj5.step_1.check(get_clustering_data)
# proj5.step_1.hint()
# proj5.step_1.solution()

# %% [markdown]
# ### Exercise 2: Elbow Method Inertia (Medium)
# Write a function `calculate_elbow_inertia(X, max_k=6)` that trains a `KMeans(n_clusters=k, random_state=42)` model for `k` from `1` to `max_k` and returns a list containing the inertia value for each trained model.

# %%
from sklearn.cluster import KMeans

def calculate_elbow_inertia(X, max_k=6):
    # TODO: Train KMeans for k=1..max_k and return list of inertias
    pass

# %%
proj5.step_2.check(calculate_elbow_inertia)
# proj5.step_2.hint()
# proj5.step_2.solution()

# %% [markdown]
# ### Exercise 3: Train K-Means Clustering (Medium)
# Write a function `train_kmeans(X, k=3)` that fits a `KMeans(n_clusters=k, random_state=42)` model on features `X` and returns its cluster label predictions (labels array).

# %%
from sklearn.cluster import KMeans

def train_kmeans(X, k=3):
    # TODO: Fit KMeans and return predicted labels array
    pass

# %%
proj5.step_3.check(train_kmeans)
# proj5.step_3.hint()
# proj5.step_3.solution()

# %% [markdown]
# ### Exercise 4: Silhouette Score Evaluation (Medium/Hard)
# Write a function `evaluate_silhouette(X, labels)` that calculates and returns the silhouette coefficient score using `sklearn.metrics.silhouette_score`.

# %%
from sklearn.metrics import silhouette_score

def evaluate_silhouette(X, labels):
    # TODO: Compute and return silhouette score
    pass

# %%
proj5.step_4.check(evaluate_silhouette)
# proj5.step_4.hint()
# proj5.step_4.solution()

# %% [markdown]
# ### Exercise 5: PCA Dimensionality Reduction (Hard)
# Write a function `apply_pca(X, n_components=2)` that fits a PCA projection model and returns the features reduced to the specified number of components.

# %%
from sklearn.decomposition import PCA

def apply_pca(X, n_components=2):
    # TODO: Project X to n_components dimensions using PCA and return array
    pass

# %%
proj5.step_5.check(apply_pca)
# proj5.step_5.hint()
# proj5.step_5.solution()

# %% [markdown]
# ### Exercise 6: Profile Cluster Centers (Hard)
# Write a function `get_cluster_profiles(df, labels)` that makes a copy of the input DataFrame, adds a column named `'Cluster'` containing the labels, groups by `'Cluster'`, and returns the mean average values for each feature (grouped columns).

# %%
def get_cluster_profiles(df, labels):
    # TODO: Copy df, assign labels to 'Cluster' column, group by Cluster, and return means
    pass

# %%
proj5.step_6.check(get_cluster_profiles)
# proj5.step_6.hint()
# proj5.step_6.solution()
